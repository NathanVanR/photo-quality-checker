# %%
import os
from datetime import datetime
from python.src.ModelTraining import model
from skl2onnx import to_onnx
from skl2onnx.common.data_types import FloatTensorType

model_dir = "../model"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

timestamp = datetime.now().strftime("%Y%m%d_%H%M")
filename = f"photo_quality_model_{timestamp}.onnx"
file_path = os.path.join(model_dir, filename)

initial_type = [('float_input', FloatTensorType([None, 3]))]
onx = to_onnx(model, initial_type)

with open(file_path, "wb") as f:
    f.write(onx.SerializeToString())

print(f"Successfully exported: {filename}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 from datetime import datetime
# ----> 3 from python.src.ModelTraining import model
#       4 from skl2onnx import to_onnx
#       5 from skl2onnx.common.data_types import FloatTensorType
#
# File ~\Documents\Coding projects\github\photo-quality-checker\python\src\ModelTraining.py:7
#       5 import os
#       6 import numpy as np
# ----> 7 from GetImageStats import get_image_stats
#       9 features = []
#      10 labels = []
#
# ModuleNotFoundError: No module named 'GetImageStats'
