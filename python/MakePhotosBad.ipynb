# %%
import cv2
import numpy as np
import os
import random

# %%
g def create_bad_dataset(input_path, output_path):

    images = [f for f in os.listdir(input_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

    for filename in images:
        img = cv2.imread(os.path.join(input_path, filename))

        failure_mode = random.choice(['blur', 'lighting', 'saturation'])

        if failure_mode == 'blur':
            processed = cv2.GaussianBlur(img, (15, 15), 0)
            label = "BLURRY"

        elif failure_mode == 'lighting':
            processed = np.clip(img.astype(float) * 0.2, 0, 255).astype(np.uint8)
            label = "DARK"

        elif failure_mode == 'saturation':
            hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
            h, s, v = cv2.split(hsv)
            s = np.clip(s.astype(float) * 0.1, 0, 255).astype(np.uint8)
            processed = cv2.cvtColor(cv2.merge([h, s, v]), cv2.COLOR_HSV2BGR)
            label = "DULL"

        new_name = f"bad_{label}_{filename}"
        cv2.imwrite(os.path.join(output_path, new_name), processed)
        print(f"Created {new_name}")

create_bad_dataset('../data/test/bad', '../data/test/bad_test')
# Out:
# Created bad_DARK_5L7A8779.jpg
# Created bad_BLURRY_5L7A8781.jpg
# Created bad_DARK_5L7A8782.jpg
# Created bad_BLURRY_5L7A8783.jpg
# Created bad_DARK_5L7A8784.jpg
# Created bad_DULL_5L7A8786.jpg
# Created bad_DULL_5L7A8787.jpg
# Created bad_DARK_5L7A8789.jpg
# Created bad_DARK_5L7A8793.jpg
# Created bad_DULL_5L7A8794.jpg
# Created bad_BLURRY_5L7A8798.jpg
# Created bad_DARK_5L7A8799.jpg
# Created bad_DARK_5L7A8800.jpg
# Created bad_BLURRY_5L7A8806.jpg
# Created bad_DARK_5L7A8807.jpg
# Created bad_BLURRY_5L7A8808.jpg
# Created bad_DULL_5L7A8811.jpg
# Created bad_BLURRY_5L7A8812.jpg
# Created bad_DULL_5L7A8814.jpg
# Created bad_DARK_5L7A8815.jpg
# Created bad_BLURRY_5L7A8816.jpg
# Created bad_DULL_5L7A8818.jpg
# Created bad_DARK_5L7A8819.jpg
# Created bad_DARK_5L7A8822.jpg
# Created bad_DARK_5L7A8824.jpg
# Created bad_DARK_5L7A8825.jpg
# Created bad_BLURRY_5L7A8826.jpg
# Created bad_BLURRY_5L7A8827.jpg
# Created bad_DULL_5L7A8829.jpg
# Created bad_BLURRY_5L7A8831.jpg
# Created bad_DULL_5L7A8832.jpg
# Created bad_DULL_5L7A8836.jpg
# Created bad_BLURRY_5L7A8837.jpg
# Created bad_DULL_5L7A8838.jpg
# Created bad_DULL_5L7A8839.jpg
# Created bad_BLURRY_5L7A8840.jpg
# Created bad_DARK_5L7A8841.jpg
# Created bad_DARK_5L7A8843.jpg
# Created bad_DULL_5L7A8844.jpg
# Created bad_BLURRY_5L7A8846.jpg
# Created bad_BLURRY_5L7A8847.jpg
# Created bad_DULL_5L7A8849.jpg
